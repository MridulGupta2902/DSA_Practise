# %%
import numpy as np
import pandas as pd
import datetime

# %%
df=pd.read_excel(r'C:\Users\Mridul\Desktop\DSA_Practise\DA Drive Assignment (2).xlsx',sheet_name="dataset")
df.loc[df["ls_19"]=='BJP']
# Out:
#                  submission_id     submission_date        ph_num  AC_num  \
# 0     610b61421c1bbf76f6f59755 2021-08-05 09:10:20  9.140540e+09   224.0
# 1     610b639e506b3b060c006dc4 2021-08-05 08:18:39  9.627410e+09    82.0
# 2     610b6bc0eb775806058eb59b 2021-08-05 09:38:57  9.997932e+09    82.0
# 4     610b7851eb775806058ebcb9 2021-08-05 10:42:35  9.678869e+09   324.0
# 8     610b95cd0d9e831428b578b0 2021-08-05 11:51:35  8.126492e+09    57.0
# ...                        ...                 ...           ...     ...
# 1986  612a44cd910d9633c93473df 2021-08-28 15:23:24  9.415779e+09   169.0
# 1992  612a4acd422b8833cf471839 2021-08-28 14:13:55  8.383004e+09   374.0
# 1997  612a551b910d9633c93482cc 2021-08-28 11:22:44  8.853965e+09   305.0
# 1998  612a552e1a296b33ec8db8e7 2021-08-28 10:14:38  8.400709e+09   305.0
# 1999  612a552f1a296b33ec8db905 2021-08-28 18:17:51  7.379768e+09   305.0
#
#                   AC   age  gender religion ls_19         vs_17  \
# ...

# %%
df.groupby(["AC"])["ls_19"].count()
# Out:
# AC
# Bahraich            25
# Bhojipura            2
# Bilgram Mallawan     1
# Bilsi                4
# Biswan              24
#                     ..
# सुल्तानपुर          15
# सैदपुर               8
# हंडिआ               18
# हरैया                9
# हुसैनगंज             8
# Name: ls_19, Length: 125, dtype: int64

# %%
df[(df['submission_date'])>datetime.datetime(2021,8,24,12,00)]
# Out:
#                  submission_id     submission_date        ph_num  AC_num  \
# 1332  61249a3c616d3e39237821a5 2021-08-24 12:13:14  6.392246e+09   303.0
# 1333  61249e48559a92391d31a71d 2021-08-24 12:22:19  6.392946e+09    58.0
# 1335  6124a14a559a92391d31acee 2021-08-24 12:50:49  6.352823e+09   162.0
# 1336  6124a2cd616d3e3923782e80 2021-08-24 12:13:45  7.096725e+09   339.0
# 1338  6124a96e98f2df3948db6cc6 2021-08-24 13:13:21  9.758229e+09    31.0
# ...                        ...                 ...           ...     ...
# 1995  612a51e51a296b33ec8db294 2021-08-28 09:04:52  8.052280e+09   296.0
# 1996  612a51e61a296b33ec8db2b8 2021-08-28 17:59:51  7.800899e+09   296.0
# 1997  612a551b910d9633c93482cc 2021-08-28 11:22:44  8.853965e+09   305.0
# 1998  612a552e1a296b33ec8db8e7 2021-08-28 10:14:38  8.400709e+09   305.0
# 1999  612a552f1a296b33ec8db905 2021-08-28 18:17:51  7.379768e+09   305.0
#
#                   AC   age  gender religion         ls_19            vs_17  \
# ...

# %%
#correlation using replace
df["satisfation_cm"].replace("कुछ हद तक संतुष्ट",0.5)
df["satisfation_PM"].replace("कुछ हद तक संतुष्ट",0.5)
# Out:
# 0         कुछ हद तक असंतुष्ट
# 1       पूरी तरह से असंतुष्ट
# 2       पूरी तरह से असंतुष्ट
# 3                        0.5
# 4       पूरी तरह से असंतुष्ट
#                 ...
# 1995                     0.5
# 1996                     0.5
# 1997     पूरी तरह से संतुष्ट
# 1998      कुछ हद तक असंतुष्ट
# 1999     पूरी तरह से संतुष्ट
# Name: satisfation_PM, Length: 2000, dtype: object
